# %% [markdown]
# EXP 0:Introduction to python

# %%
from os import setgroups
# Shardul
# 25070123155
print("Shardul Rasal")
print(2)
print([1,2,3,4,5])
x=2
y=[1,2,5]
z=("shardul rasal")
print(x,y,z,sep="\n")
# Out:
# Shardul Rasal
# 2
# [1, 2, 3, 4, 5]
# 2
# [1, 2, 5]
# shardul rasal
