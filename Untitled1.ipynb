# %%
# EXP: 1 iNTRODUCTIO TO PYTHON
# SHARDUL 25070123155
x,y,z="2","2.5",""
print(x,y,z,sep="\n")
# Out:
# Apple
# Cherry
# Orange

# %%
x,y,w,z=2,2.5,"anurag",True
print(type(x)),type(y),type(z),type(w)
# Out:
# <class 'int'>
# (None, float, bool, str)

# %% [markdown]
# # Exp 1 : introduvtion to python
# # Shardul 25070123155

# %%
a,b=10,25
print("sum=",a+b)
print("sub=",a-b)
print("mult=",a*b)
print("div=",a/b)
print("exp=",a**b)
# Out:
# sum= 35
# sub= -15
# mult= 250
# div= 0.4
# exp= 10000000000000000000000000

# %%
a=int(input("enter the value of a="))
b=int(input("enter the value of b="))
print("sum=",a+b,"\n","sub=",a-b,"\n","mult=",a*b,"\n","div=",a/b,"\n","exp=",a**b)
# Out:
# enter the value of a=2
# enter the value of b=4
# sum= 6
#  sub= -2
#  mult= 8
#  div= 0.5
#  exp= 16

# %%
import math
r=float(input("radius="))
print("Area=",math.pi*r**2)
# Out:
# radius=3
# Area= 28.274333882308138

# %%
import math
log=math.log10(10)
print("log=",log)
# Out:
# log= 1.0

# %%
a,b=10,5
if a>b:
    print("a IS THE GREATER NUMBER")
else:
    print("a is smaller than b")
# Out:
# a IS THE GREATER NUMBER
